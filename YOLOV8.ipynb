# %%
#mounting google drive and passing path
cd /content/drive/MyDrive/YoloV8_VS_MRCNN_2
# Out:
# /content/drive/MyDrive/YoloV8_VS_MRCNN_2

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
import os
HOME = os.getcwd()

# %%
print(HOME)
# Out:
# /content/drive/MyDrive/YoloV8_VS_MRCNN_2

# %%
#installing important libraries for yolo V8
# Pip install method (recommended)

# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/225.8 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/YoloV8_VS_MRCNN_2
# Out:
# /content/drive/MyDrive/YoloV8_VS_MRCNN_2

# %%
"""
#command to give detection task to our data with the help of the yaml file , passing the model and number of epochs we want.
# %cd /content/drive/MyDrive/YoloV8_VS_MRCNN_2

# !yolo task=detect mode=train model=yolov8s.pt data= data.yaml epochs=25 imgsz=384 plots=True"""
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-12-36193f45fa27>", line 1, in <cell line: 1>
#     get_ipython().run_line_magic('cd', '/content/drive/MyDrive/YoloV8_VS_MRCNN_2')
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2418, in run_line_magic
#     result = fn(*args, **kwargs)
#   File "<decorator-gen-85>", line 2, in cd
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/magic.py", line 187, in <lambda>
# ...

# %%
#getting the result for our trained model
# !ls runs/detect/train2/
# Out:
# ls: cannot access 'runs/detect/train2/': No such file or directory

# %%
#plotting confusion matrix for our model
Image(filename='runs/detect/train2/confusion_matrix.png', width=600)

# %%
Image(filename='runs/detect/train2/results.png', width=600)

# %%
Image(filename='runs/detect/train2/val_batch0_pred.jpg', width=600)

# %% [markdown]
# Validate Custom Model

# %%
#passing our model through validation dataset
# !yolo task=detect mode=val model=runs/detect/train2/weights/best.pt data=data.yaml
# Out:
# 2023-12-28 11:52:14.506838: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-28 11:52:14.506926: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-28 11:52:14.509728: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-28 11:52:15.705443: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
# ...
# 100% 755k/755k [00:00<00:00, 15.9MB/s]
# ...

# %% [markdown]
# Inference with Custom Model

# %%
#testing our model on test dataset
# !yolo task=detect mode=predict model=runs/detect/train2/weights/best.pt conf=0.25 source=data/test/images
# Out:
# 2023-12-25 17:18:10.147525: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-25 17:18:10.147596: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-25 17:18:10.149084: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-25 17:18:11.402812: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob('/content/drive/MyDrive/YoloV8_VS_MRCNN_2/runs/detect/predict/*.jpeg')[:3]:
      display(Image(filename=image_path, width=600))
      print("\n")

# %%
import os

# Specify the directory path
directory_path = '/content/drive/MyDrive/YoloV8_VS_MRCNN_2/runs/detect/predict/'

# List all files in the directory
all_files = os.listdir(directory_path)

# Filter files to only include JPEG images
image_files = [file for file in all_files if file.lower().endswith(('.jpg', '.jpeg'))]

# Print the list of image files
print("Image Files:")
print(image_files)
# Out:
# Image Files:
# []

# %%
import torch
from pathlib import Path
from PIL import Image
from IPython.display import display

# %%
#  inference on testing dataset
PATH="runs/detect/train2/"
# !yolo task=detect mode=predict model='{PATH}/weights/best.pt' save_txt=True conf=0.25 save_conf=True source='/content/drive/MyDrive/YoloV8_VS_MRCNN_2/data/test/images'
# Out:
# 2023-12-25 18:03:15.211289: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-25 18:03:15.211418: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-25 18:03:15.215300: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-25 18:03:16.767638: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-54a45a66330f> in <cell line: 1>()
# ----> 1 project.version(dataset.version).deploy(model_type="yolov8-seg", model_path=f"{HOME}/runs/segment/train/")
#
# NameError: name 'project' is not defined
